# %%
import pandas as pd

# %%
data= pd.read_csv("D:/SampleSuperstore.csv/SampleSuperstore.csv")
data
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# Shape of the dataset
data.shape
# Out:
# (9994, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # some statistical information
# Understanding the distribution of the data: The mean, min, max, and other metrics provide a quick overview of the distribution of the data.
#
# Outlier detection: The min, 25%, 75%, and max values can help identify outliers in the data.
#
# Data normalization: The mean and std values can be used to normalize the data.
#
# Feature scaling: The min, max, and other values can be used to scale the features to a suitable range.

# %% [markdown]
# data.describe()

# %%
data.describe
# Out:
# <bound method NDFrame.describe of            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]>

# %%
data.size
# Out:
# 129922

# %%
data.ndim
# Out:
# 2

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 17

# %%
data.drop_duplicates(inplace=True)

# %%
data.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
data.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023476  0.013110  0.059225 -0.029892
# Sales          -0.023476  1.000000  0.200722 -0.028311  0.479067
# Quantity        0.013110  0.200722  1.000000  0.008678  0.066211
# Discount        0.059225 -0.028311  0.008678  1.000000 -0.219662
# Profit         -0.029892  0.479067  0.066211 -0.219662  1.000000

# %% [markdown]
# # Exploratory Data Analysis - EDA

# %%
# Read the first 5 samples or rows
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# # What are the top selling products in the superstore?

# %%
# Group the data by Product Name and sum up the sales by product
product_group = data.groupby(["Sub-Category"]).sum()["Sales"]
product_group.head()
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27107.0320
# Binders        203409.1690
# Bookcases      114879.9963
# Name: Sales, dtype: float64

# %%
# Sort the data by sales in descending order
top_selling_products = product_group.sort_values(ascending=False)
top_5_selling_products = pd.DataFrame(top_selling_products.head())
top_5_selling_products
# Out:
#                    Sales
# Sub-Category
# Phones        330007.054
# Chairs        327777.761
# Storage       223843.608
# Tables        206965.532
# Binders       203409.169

# %% [markdown]
# # Plotting Top 5 selling products in superstore

# %%
# Importing matplotlib and seaborn library for plotting :
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
top_5_selling_products.plot(kind="bar")

# Add a title to the plot
plt.title("Top 5 Selling Products in Superstore")

# Add labels to the x and y axes
plt.xlabel("Product Name")
plt.ylabel("Total Profit")

# Show the plot
plt.show()

# %% [markdown]
# # top-profitable products ?

# %%
product_group = data.groupby(["Sub-Category"]).sum()["Profit"]

top_profit_products = product_group.sort_values(ascending=False)

top_5_profit_products =pd.DataFrame(top_profit_products[:5])
top_5_profit_products
# Out:
#                   Profit
# Sub-Category
# Copiers       55617.8249
# Phones        44515.7306
# Accessories   41936.6357
# Paper         33944.2395
# Binders       30228.0003

# %%
top_5_profit_products.plot(kind="bar")

plt.title("Top 5 Profit Products in Superstore")

plt.xlabel("Product Name")
plt.ylabel("Total Profit")

plt.show()

# %% [markdown]
# # Are the top-selling products the most profitable?

# %%
top_5_profit_products.index == top_5_selling_products.index
# Out:
# array([False, False, False, False,  True])

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))

# Plot the top 5 selling products in the first column
top_5_selling_products.plot(kind="bar", y="Sales", ax=ax1)

# Set the title for the first plot
ax1.set_title("Top 5 Selling Products")

# Plot the top 5 profit products in the second column
top_5_profit_products.plot(kind="bar", y="Profit", ax=ax2)

# Set the title for the second plot
ax2.set_title("Top 5 Profit Products")

# Show the plot
plt.show()

# %%
list(top_5_profit_products.index)
# Out:
# ['Copiers', 'Phones', 'Accessories', 'Paper', 'Binders']

# %%
data.Region.value_counts()
# Out:
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: Region, dtype: int64

# %%
# Filter the data to only include the Canon imageCLASS 2200 Advanced Copier
product = data[data["Sub-Category"] == "Copiers"]

# Group the data by Region
region_group = product.groupby(["Region"]).mean()[["Sales", "Profit"]]

# Ploting
region_group.plot(kind="bar")

plt.show()

# %%
# Filter the data to only include the Canon imageCLASS 2200 Advanced Copier
product = data[data["Sub-Category"] == "Phones"]

# Group the data by Region
region_group = product.groupby(["Region"]).mean()[["Sales", "Profit"]]

# Ploting
region_group.plot(kind="bar")

plt.show()

# %%
# Filter the data to only include the Canon imageCLASS 2200 Advanced Copier
product = data[data["Sub-Category"] == "Accessories"]

# Group the data by Region
region_group = product.groupby(["Region"]).mean()[["Sales", "Profit"]]

# Ploting
region_group.plot(kind="bar")

plt.show()

# %%
# Filter the data to only include the Canon imageCLASS 2200 Advanced Copier
product = data[data["Sub-Category"] == "Paper"]

# Group the data by Region
region_group = product.groupby(["Region"]).mean()[["Sales", "Profit"]]

# Ploting
region_group.plot(kind="bar")

plt.show()

# %%
# Filter the data to only include the Canon imageCLASS 2200 Advanced Copier
product = data[data["Sub-Category"] == "Binders"]

# Group the data by Region
region_group = product.groupby(["Region"]).mean()[["Sales", "Profit"]]

# Ploting
region_group.plot(kind="bar")

plt.show()

# %%
product = data[(data["Sub-Category"] == "Binders") & (data["Region"] == "Central")]
product
# Out:
#            Ship Mode      Segment        Country          City      State  \
# 15    Standard Class  Home Office  United States    Fort Worth      Texas
# 45       First Class    Corporate  United States         Eagan  Minnesota
# 49    Standard Class     Consumer  United States    New Albany    Indiana
# 75       First Class    Corporate  United States       Houston      Texas
# 94      Second Class     Consumer  United States   Minneapolis  Minnesota
# ...              ...          ...            ...           ...        ...
# 9795  Standard Class    Corporate  United States       Chicago   Illinois
# 9808  Standard Class     Consumer  United States       Chicago   Illinois
# 9835     First Class     Consumer  United States      La Porte      Texas
# 9920  Standard Class    Corporate  United States         Bryan      Texas
# 9951    Second Class    Corporate  United States  Indianapolis    Indiana
#
#       Postal Code   Region         Category Sub-Category   Sales  Quantity  \
# 15          76106  Central  Office Supplies      Binders   2.544         3
# 45          55122  Central  Office Supplies      Binders  17.460         2
# 49          47150  Central  Office Supplies      Binders  38.220         6
# 75          77041  Central  Office Supplies      Binders   1.248         3
# 94          55407  Central  Office Supplies      Binders  32.960         2
# ...           ...      ...              ...          ...     ...       ...
# 9795        60610  Central  Office Supplies      Binders   3.798         3
# 9808        60623  Central  Office Supplies      Binders   2.112         2
# 9835        77571  Central  Office Supplies      Binders  16.392         2
# 9920        77803  Central  Office Supplies      Binders  22.386         7
# 9951        46203  Central  Office Supplies      Binders  17.380         2
#
#       Discount   Profit
# 15         0.8  -3.8160
# 45         0.0   8.2062
# 49         0.0  17.9634
# 75         0.8  -1.9344
# 94         0.0  16.1504
# ...        ...      ...
# 9795       0.8  -5.8869
# 9808       0.8  -3.3792
# 9835       0.8 -26.2272
# 9920       0.8 -35.8176
# 9951       0.0   8.6900
#
# [365 rows x 13 columns]

# %%
product = data[(data["Sub-Category"] == "Binders") & (data["Region"] == "Central")]

# Plot a histogram of the discounts offered for the product in the central region
product["Discount"].plot(kind="hist")

# Show the plot
plt.show()
product
# Out:
#            Ship Mode      Segment        Country          City      State  \
# 15    Standard Class  Home Office  United States    Fort Worth      Texas
# 45       First Class    Corporate  United States         Eagan  Minnesota
# 49    Standard Class     Consumer  United States    New Albany    Indiana
# 75       First Class    Corporate  United States       Houston      Texas
# 94      Second Class     Consumer  United States   Minneapolis  Minnesota
# ...              ...          ...            ...           ...        ...
# 9795  Standard Class    Corporate  United States       Chicago   Illinois
# 9808  Standard Class     Consumer  United States       Chicago   Illinois
# 9835     First Class     Consumer  United States      La Porte      Texas
# 9920  Standard Class    Corporate  United States         Bryan      Texas
# 9951    Second Class    Corporate  United States  Indianapolis    Indiana
#
#       Postal Code   Region         Category Sub-Category   Sales  Quantity  \
# 15          76106  Central  Office Supplies      Binders   2.544         3
# 45          55122  Central  Office Supplies      Binders  17.460         2
# 49          47150  Central  Office Supplies      Binders  38.220         6
# 75          77041  Central  Office Supplies      Binders   1.248         3
# 94          55407  Central  Office Supplies      Binders  32.960         2
# ...           ...      ...              ...          ...     ...       ...
# 9795        60610  Central  Office Supplies      Binders   3.798         3
# 9808        60623  Central  Office Supplies      Binders   2.112         2
# 9835        77571  Central  Office Supplies      Binders  16.392         2
# 9920        77803  Central  Office Supplies      Binders  22.386         7
# 9951        46203  Central  Office Supplies      Binders  17.380         2
#
#       Discount   Profit
# 15         0.8  -3.8160
# 45         0.0   8.2062
# 49         0.0  17.9634
# 75         0.8  -1.9344
# 94         0.0  16.1504
# ...        ...      ...
# 9795       0.8  -5.8869
# 9808       0.8  -3.3792
# 9835       0.8 -26.2272
# 9920       0.8 -35.8176
# 9951       0.0   8.6900
#
# [365 rows x 13 columns]

# %% [markdown]
# # Which region & place generates the most sales?

# %%
df_places = data[['Country','City','State','Region']]
df_places.head()
# Out:
#          Country             City       State Region
# 0  United States        Henderson    Kentucky  South
# 1  United States        Henderson    Kentucky  South
# 2  United States      Los Angeles  California   West
# 3  United States  Fort Lauderdale     Florida  South
# 4  United States  Fort Lauderdale     Florida  South

# %%
df_places = data[['City','State','Region','Sales','Profit']]
df_places.head()
# Out:
#               City       State Region     Sales    Profit
# 0        Henderson    Kentucky  South  261.9600   41.9136
# 1        Henderson    Kentucky  South  731.9400  219.5820
# 2      Los Angeles  California   West   14.6200    6.8714
# 3  Fort Lauderdale     Florida  South  957.5775 -383.0310
# 4  Fort Lauderdale     Florida  South   22.3680    2.5164

# %%
# Group the data by Region and City and calculate the total sales for each group
region_sales = df_places.groupby(['Region'], as_index=False).sum()
region_sales.sort_values(by='Sales', ascending=False, inplace=True)

# Plot the total sales geProfitnerated by each region and city
plt.figure(figsize=(5,5))
plt.bar(region_sales['Region'], region_sales['Sales'], align='center',)
plt.xlabel("Region")
plt.ylabel("Sales")
plt.title("Sales Generated by Region")
plt.xticks(rotation=50)
plt.show()
region_sales
# Out:
#     Region        Sales       Profit
# 3     West  725255.6365  108329.8079
# 1     East  678435.1960   91506.3092
# 0  Central  500782.8528   39655.8752
# 2    South  391721.9050   46749.4303

# %%
# Group the data by Region and City and calculate the total sales for each group
region_profit = df_places.groupby(['Region'], as_index=False).sum()
region_profit.sort_values(by='Profit', ascending=False, inplace=True)

# Plot the total sales generated by each region and city
plt.figure(figsize=(5,5))
plt.bar(region_profit['Region'], region_profit['Profit'], align='center',)
plt.xlabel("Region")
plt.ylabel("Profit")
plt.title("Profit Generated by Region")
plt.xticks(rotation=90)
plt.show()
region_profit
# Out:
#     Region        Sales       Profit
# 3     West  725255.6365  108329.8079
# 1     East  678435.1960   91506.3092
# 2    South  391721.9050   46749.4303
# 0  Central  500782.8528   39655.8752

# %%
state_sales = df_places.groupby(['State'], as_index=False).sum()
state_sales.sort_values(by='Sales', ascending=False, inplace=True)


plt.figure(figsize=(22,15))
plt.bar(state_sales['State'], state_sales['Sales'], align='center',)
plt.xlabel("State")
plt.ylabel("Sales")
plt.title("Sales Generated by State")
plt.xticks(rotation=90)

plt.show()
state_sales
# Out:
#                    State        Sales      Profit
# 3             California  457576.2715  76330.7891
# 30              New York  310827.1510  74015.4622
# 41                 Texas  170124.5418 -25750.9833
# 45            Washington  138560.8100  33368.2375
# 36          Pennsylvania  116496.3620 -15565.4035
# 8                Florida   89473.7080  -3399.3017
# 11              Illinois   80162.5370 -12601.6500
# 33                  Ohio   77976.7640 -16959.3178
# 20              Michigan   75879.6440  24428.0903
# 44              Virginia   70636.7200  18597.9504
# 31        North Carolina   55603.1640  -7490.9122
# 12               Indiana   53555.3600  18382.9363
# 9                Georgia   49095.8400  16250.0433
# 15              Kentucky   36591.7500  11199.6966
# 28            New Jersey   35764.3120   9772.9138
# 1                Arizona   35282.0010  -3427.9246
# 47             Wisconsin   32114.6100   8401.8004
# 4               Colorado   32108.1180  -6527.8579
# 40             Tennessee   30661.8730  -5341.6936
# 21             Minnesota   29863.1500  10823.1874
# 19         Massachusetts   28634.4340   6785.5016
# 6               Delaware   27451.0690   9977.3748
# 18              Maryland   23705.5230   7031.1788
# 37          Rhode Island   22627.9560   7285.6293
# 23              Missouri   22205.1500   6436.2105
# 34              Oklahoma   19683.3900   4853.9560
# 0                Alabama   19510.6400   5786.8253
# 35                Oregon   17420.7820  -1194.0993
# 26                Nevada   16729.1020   3316.7659
# 5            Connecticut   13384.3570   3511.4918
# 2               Arkansas   11678.1300   4008.6871
# 42                  Utah   11220.0560   2546.5335
# 22           Mississippi   10771.3400   3172.9762
# 16             Louisiana    9217.0300   2196.1023
# 43               Vermont    8929.3700   2244.9783
# 38        South Carolina    8481.7100   1769.0566
# 25              Nebraska    7464.9300   2037.0942
# 27         New Hampshire    7292.5240   1706.5028
# 24               Montana    5589.3520   1833.3285
# 29            New Mexico    4783.5220   1157.1161
# 13                  Iowa    4579.7600   1183.8119
# 10                 Idaho    4382.4860    826.7231
# 14                Kansas    2914.3100    836.4435
# 7   District of Columbia    2865.0200   1059.5893
# 48               Wyoming    1603.1360    100.1960
# 39          South Dakota    1315.5600    394.8283
# 17                 Maine    1270.5300    454.4862
# 46         West Virginia    1209.8240    185.9216
# 32          North Dakota     919.9100    230.1497

# %%
state_profit = df_places.groupby(['State'], as_index=False).sum()
state_profit.sort_values(by='Profit', ascending=False, inplace=True)


plt.figure(figsize=(22,10))
plt.bar(state_profit['State'], state_profit['Profit'], align='center',)
plt.xlabel("State")
plt.ylabel("Profit")
plt.title("Sales Generated by State")
plt.xticks(rotation=90)

plt.show()
state_profit
# Out:
#                    State        Sales      Profit
# 3             California  457576.2715  76330.7891
# 30              New York  310827.1510  74015.4622
# 45            Washington  138560.8100  33368.2375
# 20              Michigan   75879.6440  24428.0903
# 44              Virginia   70636.7200  18597.9504
# 12               Indiana   53555.3600  18382.9363
# 9                Georgia   49095.8400  16250.0433
# 15              Kentucky   36591.7500  11199.6966
# 21             Minnesota   29863.1500  10823.1874
# 6               Delaware   27451.0690   9977.3748
# 28            New Jersey   35764.3120   9772.9138
# 47             Wisconsin   32114.6100   8401.8004
# 37          Rhode Island   22627.9560   7285.6293
# 18              Maryland   23705.5230   7031.1788
# 19         Massachusetts   28634.4340   6785.5016
# 23              Missouri   22205.1500   6436.2105
# 0                Alabama   19510.6400   5786.8253
# 34              Oklahoma   19683.3900   4853.9560
# 2               Arkansas   11678.1300   4008.6871
# 5            Connecticut   13384.3570   3511.4918
# 26                Nevada   16729.1020   3316.7659
# 22           Mississippi   10771.3400   3172.9762
# 42                  Utah   11220.0560   2546.5335
# 43               Vermont    8929.3700   2244.9783
# 16             Louisiana    9217.0300   2196.1023
# 25              Nebraska    7464.9300   2037.0942
# 24               Montana    5589.3520   1833.3285
# 38        South Carolina    8481.7100   1769.0566
# 27         New Hampshire    7292.5240   1706.5028
# 13                  Iowa    4579.7600   1183.8119
# 29            New Mexico    4783.5220   1157.1161
# 7   District of Columbia    2865.0200   1059.5893
# 14                Kansas    2914.3100    836.4435
# 10                 Idaho    4382.4860    826.7231
# 17                 Maine    1270.5300    454.4862
# 39          South Dakota    1315.5600    394.8283
# 32          North Dakota     919.9100    230.1497
# 46         West Virginia    1209.8240    185.9216
# 48               Wyoming    1603.1360    100.1960
# 35                Oregon   17420.7820  -1194.0993
# 8                Florida   89473.7080  -3399.3017
# 1                Arizona   35282.0010  -3427.9246
# 40             Tennessee   30661.8730  -5341.6936
# 4               Colorado   32108.1180  -6527.8579
# 31        North Carolina   55603.1640  -7490.9122
# 11              Illinois   80162.5370 -12601.6500
# 36          Pennsylvania  116496.3620 -15565.4035
# 33                  Ohio   77976.7640 -16959.3178
# 41                 Texas  170124.5418 -25750.9833

# %%
city_sales = df_places.groupby('City', as_index=False).sum()

# Sort the data by Sales in descending order
city_sales.sort_values(by='Sales', ascending=False, inplace=True)

# Select the top 5 cities
top_5_cities_sales = city_sales.head()

plt.bar(top_5_cities_sales['City'], top_5_cities_sales['Sales'], align='center')
plt.xlabel("City")
plt.ylabel("Sales")
plt.title("Top 5 Cities by Sales")
plt.xticks(rotation=90)
plt.show()
top_5_cities_sales
# Out:
#               City       Sales      Profit
# 329  New York City  256319.041  62013.8973
# 266    Los Angeles  175831.901  30431.4267
# 452        Seattle  119460.282  29121.6825
# 438  San Francisco  112577.172  17466.1186
# 374   Philadelphia  109061.461 -13843.2106

# %%
city_profit = df_places.groupby('City', as_index=False).sum()

# Sort the data by Sales in descending order
city_profit.sort_values(by='Profit', ascending=False, inplace=True)

# Select the top 5 cities
top_5_cities_profit =city_profit.head()

plt.bar(top_5_cities_profit['City'], top_5_cities_profit['Profit'], align='center')
plt.xlabel("City")
plt.ylabel("Profit")
plt.title("Top 5 Cities by Profit")
plt.xticks(rotation=90)

plt.show()
top_5_cities_profit
# Out:
#               City       Sales      Profit
# 329  New York City  256319.041  62013.8973
# 266    Los Angeles  175831.901  30431.4267
# 452        Seattle  119460.282  29121.6825
# 438  San Francisco  112577.172  17466.1186
# 123        Detroit   42056.974  13146.6935

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
data.Discount.value_counts()
# Out:
# 0.00    4787
# 0.20    3653
# 0.70     418
# 0.80     299
# 0.30     226
# 0.40     206
# 0.60     138
# 0.10      94
# 0.50      66
# 0.15      52
# 0.32      27
# 0.45      11
# Name: Discount, dtype: int64

# %%
# Group the data by the discount and compute the average sales
discount_group = data.groupby(["Discount"]).mean()[["Sales"]]

ax = discount_group.plot(kind="bar")

ax.set_ylabel("Sales")

plt.show()

# %%
# Create a scatter plot between sales and discounts
plt.scatter(data['Sales'],data['Discount'])

plt.ylabel("Discount")
plt.xlabel("Sales")
plt.show()

# %%
# Group the data by the discount and compute the average sales
discount_group = data.groupby(["Discount"]).sum()[["Profit"]]

ax = discount_group.plot(kind="bar")

ax.set_ylabel("Profit")

plt.show()

# %% [markdown]
# # The best sales
#
# The best sales are when the discount is 50%, but this leads to loss and non-profitability.
#
# The discount from 10 to 20%. Is the best solution, as they are the second and third best sellers and make profits

# %%
# Group the data by product category and calculate the average profit for each category
avg_profit_margin_by_category = data.groupby('Category')['Profit'].sum()

print(avg_profit_margin_by_category)
# Out:
# Category
# Furniture           18421.8137
# Office Supplies    122364.6608
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
data['Profit Margin'] = data['Profit'] / data['Sales']

# Group the data by product category and calculate the average profit margin for each category
avg_profit_margin_by_category = data.groupby('Category')['Profit Margin'].mean()

# Plot the average profit margin for each category as a bar chart
avg_profit_margin_by_category.plot(kind='bar')

# Add a title and labels to the chart
plt.title("Average Profit Margin by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Average Profit Margin")

plt.show()

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit  Profit Margin
# 0      0.00   41.9136         0.1600
# 1      0.00  219.5820         0.3000
# 2      0.00    6.8714         0.4700
# 3      0.45 -383.0310        -0.4000
# 4      0.20    2.5164         0.1125

# %%
data.Segment.value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
data['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %%
pivot_table = data.pivot_table(index='Segment', columns='Ship Mode', values='Sales', aggfunc='sum')
pivot_table
# Out:
# Ship Mode    First Class   Same Day  Second Class  Standard Class
# Segment
# Consumer     159121.0130  60596.359   231485.9896     709629.4134
# Corporate    105858.4699  45121.323   146122.4748     408967.8631
# Home Office   86400.9880  22604.043    81568.5810     238719.0725

# %%
# Plot the pivot table as a bar chart
pivot_table.plot(kind='bar', stacked=False)
plt.show()

# %%
#profit
pivot_table = data.pivot_table(index='Segment', columns='Ship Mode', values='Profit', aggfunc='sum')

pivot_table.plot(kind='bar', stacked=False)

# Show the plot
plt.show()

# %%
import seaborn as sns
ax=sns.heatmap(data.corr(),annot=True,cbar=True,square=True,linecolor="blue",linewidths=1,xticklabels="auto",yticklabels="auto",fmt=".2f")
ax.set(xlabel="", ylabel="")
ax.xaxis.tick_top()

# %% [markdown]
# # building model

# %%
from sklearn.linear_model import LinearRegression
col=['Ship Mode','Segment','Country','City','State','Postal Code','Region','Category','Sub-Category','Quantity','Discount']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
df=data.drop(columns=col,axis=1)
df1=df.copy()
x=df1.drop(["Profit"],axis="columns",inplace=False)

# %%
y=df1["Profit"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=3/5,random_state=0)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
reg=LinearRegression()
reg=reg.fit(x,y)
# Out:
# (3990, 2) (5987, 2) (3990,) (5987,)

# %%
prediction_lin1=reg.predict(x)
#computing MSE and RMSE
import numpy as np
from sklearn.metrics import mean_squared_error
lin_mse1=mean_squared_error(y,prediction_lin1)
print(np.log(lin_mse1))
# Out:
# 10.587466648229803

# %%
#R_squared value
r2_lin_test1=reg.score(x_test,y_test)
r2_lin_train1=reg.score(x_train,y_train)
print(r2_lin_test1,r2_lin_train1)
# Out:
# 0.2906850313207624 0.26118446444875787
